# %%
import numpy as np
import matplotlib.pyplot as plt

A = [-2,6]
B = [2.2426406871192834, 1.7573593128807135]
C = [4.3639610306789258, 3.8786796564403558]

D = [2.4852813742385611,2.4852813742385611]
E = [-3.1715728752538128,-6]
F = [-0.34314575050762608, -6]

points1 = [A,B,C,A]
points2 = [D,E,F, D]

plt.plot([i[0] for i in points1],[i[1] for i in points1])
plt.plot([i[0] for i in points2],[i[1] for i in points2])
plt.show()
